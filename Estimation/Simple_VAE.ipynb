# %%
import torch
import torch.nn as nn

import numpy as np

# %%
dataset_path = 'datasets'

# Change this to True if you have NVidia GPU
cuda = False
DEVICE = torch.device("cuda" if cuda else "cpu")

hidden_dim = 400
latent_dim = 200

lr = 1e-3

epochs = 30
